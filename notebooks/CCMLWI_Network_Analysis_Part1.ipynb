# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('C:/Aumkar/Data Science Masters/Sem 4/Cognitive Computational Modeling of Language and Web Interaction/Assignment 4/wg5-network analysis/wg6-network analysis/sociogram-employees-un.csv', header = None)

# %%
g = nx.DiGraph(df.as_matrix())

# %%
pos = nx.spring_layout(g, scale = 10)

# %%
labels={}
labels[0]=r'$A$'
labels[1]=r'$B$'
labels[2]=r'$C$'
labels[3]=r'$D$'
labels[4]=r'$E$'
labels[5]=r'$F$'
labels[6]=r'$G$'
labels[7]=r'$H$'
labels[8]=r'$I$'
labels[9]=r'$J$'
labels[10]=r'$K$'
labels[11]=r'$L$'
labels[12]=r'$M$'
labels[13]=r'$N$'
labels[14]=r'$O$'
labels[15]=r'$P$'
labels[16]=r'$Q$'
labels[17]=r'$R$'
labels[18]=r'$S$'
labels[19]=r'$T$'
labels[20]=r'$U$'
labels[21]=r'$V$'
labels[22]=r'$W$'
labels[23]=r'$X$'
labels[24]=r'$Y$'

# %%
nx.draw_networkx(g, pos, with_labels = True, node_color = 'yellow', edge_color = 'grey', labels = labels, arrowsize = 0.2)

# %%
plt.show()

# %%
g_diameter = nx.diameter(g)

# %%
g_diameter
# Out:
# 3

# %%
closeness_ = nx.closeness_centrality(g)

# %%
avg_closenness = np.mean(list(closeness_.values()))

# %%
betweenness_ = nx.betweenness_centrality(g)

# %%
avg_betweenness = np.mean(list(betweenness_.values()))

# %%
network_density = nx.density(g)

# %%
degree_ = nx.degree(g)

# %%
avg_degree = np.mean(list(degree_.values()))

# %%
network_reciprocity = nx.algorithms.reciprocity.reciprocity(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e5f21d7de597> in <module>()
# ----> 1 network_reciprocity = nx.algorithms.reciprocity.reciprocity(g)
#
# AttributeError: module 'networkx.algorithms' has no attribute 'reciprocity'

# %%
network_transitivity = nx.transitivity(g)

# %%
network_transitivity
# Out:
# 0.4971969166082691

# %%
eccentricity = nx.algorithms.distance_measures.eccentricity(g)

# %%
avg_eccentricity = np.mean(list(eccentricity.values()))

# %%
hubs_mat = nx.algorithms.link_analysis.hits_alg.hub_matrix(g)

# %%
len(hubs_mat)
# Out:
# 25

# %%
hubs_auth_vals = nx.algorithms.link_analysis.hits_alg.hits_numpy(g)

# %%
hubs_auth_vals
# Out:
# ({0: 0.05415923534077656,
#   1: 0.040492700060209406,
#   2: 0.03785053980925029,
#   3: 0.03965034937653514,
#   4: 0.04107848639854548,
#   5: 0.04882038177237041,
#   6: 0.041424409665646166,
#   7: 0.045236573909518074,
#   8: 0.034915580324305535,
#   9: 0.047096344768125055,
#   10: 0.04729362848641266,
#   11: 0.038050949614381886,
#   12: 0.041138296475784555,
#   13: 0.03409631908461891,
#   14: 0.03436621655691654,
#   15: 0.039788063752839525,
#   16: 0.036348459527972096,
#   17: 0.0400939191234302,
#   18: 0.028775798181014414,
#   19: 0.03269209171965116,
#   20: 0.04047813348449841,
#   21: 0.04138770779874904,
#   22: 0.042292022748736516,
#   23: 0.02746950364454765,
#   24: 0.045004288375164236},
#  {0: 0.030242483822909273,
#   1: 0.049664201540795365,
#   2: 0.035706200370648415,
#   3: 0.07318150943861856,
#   4: 0.02887702521065505,
#   5: 0.013933568493352538,
#   6: 0.04114958152215443,
#   7: 0.02390532555642829,
#   8: 0.05523739700994836,
#   9: 0.019471044370995352,
#   10: 0.05026505201581732,
#   11: 0.05392031314408895,
#   12: 0.02077163410083211,
#   13: 0.05453615085270038,
#   14: 0.040194525326742635,
#   15: 0.03590447520675922,
#   16: 0.04710711024152895,
#   17: 0.037347666850635584,
#   18: 0.04366091525929447,
#   19: 0.01853258463198512,
#   20: 0.030928864553929493,
#   21: 0.0651478332078731,
#   22: 0.03863282477595494,
#   23: 0.058928281190451945,
#   24: 0.03275343130490015})

# %%
hubs_sorted = sorted(hubs_auth_vals[0], key = lambda k: hubs_auth_vals[0][k])

# %%
hubs_sorted
# Out:
# [23,
#  18,
#  19,
#  13,
#  14,
#  8,
#  16,
#  2,
#  11,
#  3,
#  15,
#  17,
#  20,
#  1,
#  4,
#  12,
#  21,
#  6,
#  22,
#  24,
#  7,
#  9,
#  10,
#  5,
#  0]
